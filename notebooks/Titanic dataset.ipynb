# %%
import pandas as pd
import numpy as np
import os 
# df = pd.read_csv(path, header=None)
path = "C:\\Users\\BLESS\\Desktop\\titanic\\data\\raw\\train.csv"
df_train = pd.read_csv(path)

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_train.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Augustsson, Mr. Albert  male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare    Cabin  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_test.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d1f581aefaf0> in <module>
# ----> 1 df_test.tail(10)
#
# NameError: name 'df_test' is not defined

# %%
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
path2 = "C:\\Users\\BLESS\\Desktop\\titanic\\data\\raw\\test.csv"
df_test = pd.read_csv(path2)

# %%
df_test.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
df_test.describe(include = "all")
# Out:
#         PassengerId      Pclass                            Name   Sex  \
# count    418.000000  418.000000                             418   418
# unique          NaN         NaN                             418     2
# top             NaN         NaN  Duran y More, Miss. Florentina  male
# freq            NaN         NaN                               1   266
# mean    1100.500000    2.265550                             NaN   NaN
# std      120.810458    0.841838                             NaN   NaN
# min      892.000000    1.000000                             NaN   NaN
# 25%      996.250000    1.000000                             NaN   NaN
# 50%     1100.500000    3.000000                             NaN   NaN
# 75%     1204.750000    3.000000                             NaN   NaN
# max     1309.000000    3.000000                             NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# ...

# %%
df_test.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
missing_data = df_test.isnull()

for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# PassengerId
# False    418
# Name: PassengerId, dtype: int64
#
# Pclass
# False    418
# Name: Pclass, dtype: int64
#
# Name
# False    418
# Name: Name, dtype: int64
#
# Sex
# False    418
# Name: Sex, dtype: int64
#
# Age
# False    332
# True      86
# Name: Age, dtype: int64
#
# SibSp
# False    418
# Name: SibSp, dtype: int64
#
# Parch
# False    418
# Name: Parch, dtype: int64
#
# Ticket
# False    418
# Name: Ticket, dtype: int64
#
# Fare
# False    417
# True       1
# Name: Fare, dtype: int64
#
# Cabin
# True     327
# False     91
# Name: Cabin, dtype: int64
#
# Embarked
# False    418
# Name: Embarked, dtype: int64

# %%
#path = "C:\\Users\\BLESS\\Desktop\\titanic\\data\\raw\\train.csv"
#df = pd.read_csv(path)
type(df_test)
# Out:
# pandas.core.frame.DataFrame

# %%
df_test['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df_test[['Age','Name']]
# Out:
#       Age                                          Name
# 0    34.5                              Kelly, Mr. James
# 1    47.0              Wilkes, Mrs. James (Ellen Needs)
# 2    62.0                     Myles, Mr. Thomas Francis
# 3    27.0                              Wirz, Mr. Albert
# 4    22.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..    ...                                           ...
# 413   NaN                            Spector, Mr. Woolf
# 414  39.0                  Oliva y Ocana, Dona. Fermina
# 415  38.5                  Saether, Mr. Simon Sivertsen
# 416   NaN                           Ware, Mr. Frederick
# 417   NaN                      Peter, Master. Michael J
#
# [418 rows x 2 columns]

# %%
df_test[['Age','Name','Pclass']]
# Out:
#       Age                                          Name  Pclass
# 0    34.5                              Kelly, Mr. James       3
# 1    47.0              Wilkes, Mrs. James (Ellen Needs)       3
# 2    62.0                     Myles, Mr. Thomas Francis       2
# 3    27.0                              Wirz, Mr. Albert       3
# 4    22.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)       3
# ..    ...                                           ...     ...
# 413   NaN                            Spector, Mr. Woolf       3
# 414  39.0                  Oliva y Ocana, Dona. Fermina       1
# 415  38.5                  Saether, Mr. Simon Sivertsen       3
# 416   NaN                           Ware, Mr. Frederick       3
# 417   NaN                      Peter, Master. Michael J       3
#
# [418 rows x 3 columns]

# %% [markdown]
# # Putting both the test and train data together

# %%
df = pd.concat((df_train,df_test),axis = 0)
df.set_index("PassengerId",inplace = True)

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.describe(include = 'all')
# Out:
#           Survived       Pclass                  Name   Sex          Age  \
# count   891.000000  1309.000000                  1309  1309  1046.000000
# unique         NaN          NaN                  1307     2          NaN
# top            NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq           NaN          NaN                     2   843          NaN
# mean      0.383838     2.294882                   NaN   NaN    29.881138
# std       0.486592     0.837836                   NaN   NaN    14.413493
# min       0.000000     1.000000                   NaN   NaN     0.170000
# 25%       0.000000     2.000000                   NaN   NaN    21.000000
# 50%       0.000000     3.000000                   NaN   NaN    28.000000
# 75%       1.000000     3.000000                   NaN   NaN    39.000000
# max       1.000000     3.000000                   NaN   NaN    80.000000
#
#               SibSp        Parch    Ticket         Fare        Cabin Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 122.7+ KB

# %%
df.loc[5:15,:]
# Out:
#              Survived  Pclass  \
# PassengerId
# 5                 0.0       3
# 6                 0.0       3
# 7                 0.0       1
# 8                 0.0       3
# 9                 1.0       3
# 10                1.0       2
# 11                1.0       3
# 12                1.0       1
# 13                0.0       3
# 14                0.0       3
# 15                0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...

# %%
male_pas = df.loc[df.Sex == 'male',:]
print("number of male pass : {}".format(len(male_pas)))
# Out:
# number of male pass : 843

# %%
print('mean fare: {}'.format(df.Fare.mean()))
# Out:
# mean fare: 33.2954792813456

# %%
df.Fare.median()
# Out:
# 14.4542

# %%
df.Fare.plot(kind = 'box')

# %%
# %matplotlib inline
df.Pclass.value_counts().plot(kind = 'bar',rot= '0')

# %%
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %% [markdown]
# # Data Distribution

# %% [markdown]
# ## univariate distribution: "Histogram"

# %%
df.Age.plot(kind = "hist",title = "Histogram for Age dist",color = "c",bins = 30)

# %% [markdown]
# ## KDE Plot

# %%
df.Age.plot(kind = "kde",title = "Histogram for Age dist",color = "c");

# %% [markdown]
# ## Checking for skewness

# %%
df.Age.skew()
# Out:
# 0.40767455974362266

# %%
print("skewness for Age: {0:.2f}".format(df.Age.skew()))
# Out:
# skewness for Age: 0.41

# %% [markdown]
# ## Bivariate distribution

# %% [markdown]
# ### Scatter plot

# %%
df.plot.scatter(x= "Parch",y= "Fare" ,color = "c",title = "Parch vrs Fare");

# %% [markdown]
# ## Grouping/Agregation

# %%
df.groupby("Sex").Age.mean()
# Out:
# Sex
# female    28.687088
# male      30.585228
# Name: Age, dtype: float64

# %%
df.groupby(["Pclass","Fare"]).mean()
# Out:
#                 Survived        Age     SibSp     Parch
# Pclass Fare
# 1      0.0000   0.000000  41.500000  0.000000  0.000000
#        5.0000   0.000000  33.000000  0.000000  0.000000
#        25.5875  0.000000  47.000000  0.000000  0.000000
#        25.7000       NaN  55.000000  2.000000  0.000000
#        25.7417       NaN        NaN  0.000000  0.000000
# ...                  ...        ...       ...       ...
# 3      34.3750  0.000000  22.400000  1.600000  2.400000
#        39.6875  0.000000  14.714286  2.857143  1.428571
#        46.9000  0.000000  18.000000  4.000000  3.000000
#        56.4958  0.714286  29.500000  0.000000  0.000000
#        69.5500  0.000000  14.500000  6.727273  3.272727
#
# [288 rows x 4 columns]

# %%
df.groupby(['Pclass']).agg({'Fare':'mean','Age':'median'})
# Out:
#              Fare   Age
# Pclass
# 1       87.508992  39.0
# 2       21.179196  29.0
# 3       13.302889  24.0

# %% [markdown]
# ## CrossTab

# %%
pd.crosstab(df.Sex,df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female  144  106  216
# male    179  171  493

# %%
df.Survived.value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
pd.crosstab(df.Sex,df.Survived)
# Out:
# Survived  0.0  1.0
# Sex
# female     81  233
# male      468  109

# %%
pd.crosstab(df.Sex,df.Pclass).plot(kind = 'bar');

# %% [markdown]
# ## Pivot Table

# %%
df.pivot_table(index='Sex',columns= 'Pclass',values = 'Age',aggfunc = 'mean')
# Out:
# Pclass          1          2          3
# Sex
# female  37.037594  27.499223  22.185329
# male    41.029272  30.815380  25.962264

# %% [markdown]
# # Data Munging

# %% [markdown]
# ## Dealing With Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 162.7+ KB

# %%
df[df.Embarked.isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                1.0       1                        Icard, Miss. Amelie
# 830               1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].Embarked)
# Out:
# Embarked   C   Q    S
# Survived
# 0.0       75  47  427
# 1.0       93  30  217

# %%
df.groupby(['Pclass', 'Embarked']).Fare.median()
# Out:
# Pclass  Embarked
# 1       C           76.7292
#         Q           90.0000
#         S           52.0000
# 2       C           15.3146
#         Q           12.3500
#         S           15.3750
# 3       C            7.8958
#         Q            7.7500
#         S            8.0500
# Name: Fare, dtype: float64

# %%
df.Embarked.fillna('C',inplace = True)

# %%
df[df.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
#              Survived  Pclass                Name   Sex   Age  SibSp  Parch  \
# PassengerId
# 1044              NaN       3  Storey, Mr. Thomas  male  60.5      0      0
#
#             Ticket  Fare Cabin Embarked
# PassengerId
# 1044          3701   NaN   NaN        S

# %%
MedianFare = df.loc[(df.Pclass == 3) & (df.Embarked == 'S'), 'Fare'].median()
print(MedianFare)
# Out:
# 8.05

# %%
df.Fare.fillna(MedianFare,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1309 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1309 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 162.7+ KB

# %%
pd.options.display.max_rows = 15

# %%
df[df.Age.isnull()]
# Out:
#              Survived  Pclass                             Name     Sex  Age  \
# PassengerId
# 6                 0.0       3                 Moran, Mr. James    male  NaN
# 18                1.0       2     Williams, Mr. Charles Eugene    male  NaN
# 20                1.0       3          Masselmani, Mrs. Fatima  female  NaN
# 27                0.0       3          Emir, Mr. Farred Chehab    male  NaN
# 29                1.0       3    O'Dwyer, Miss. Ellen "Nellie"  female  NaN
# ...               ...     ...                              ...     ...  ...
# 1300              NaN       3  Riordan, Miss. Johanna Hannah""  female  NaN
# 1302              NaN       3           Naughton, Miss. Hannah  female  NaN
# 1305              NaN       3               Spector, Mr. Woolf    male  NaN
# 1308              NaN       3              Ware, Mr. Frederick    male  NaN
# 1309              NaN       3         Peter, Master. Michael J    male  NaN
#
# ...

# %%
df.Name
# Out:
# PassengerId
# 1                                 Braund, Mr. Owen Harris
# 2       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss. Laina
# 4            Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                Allen, Mr. William Henry
#                               ...
# 1305                                   Spector, Mr. Woolf
# 1306                         Oliva y Ocana, Dona. Fermina
# 1307                         Saether, Mr. Simon Sivertsen
# 1308                                  Ware, Mr. Frederick
# 1309                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
def GetTitle(name):
    first_name = name.split(',')[1]
    title = first_name.split('.')[0]
    title = title.strip().lower()
    return title

# %%
df.Name.map(lambda x : GetTitle(x))
# Out:
# PassengerId
# 1           mr
# 2          mrs
# 3         miss
# 4          mrs
# 5           mr
#          ...
# 1305        mr
# 1306      dona
# 1307        mr
# 1308        mr
# 1309    master
# Name: Name, Length: 1309, dtype: object

# %%
df.Name.map(lambda x : GetTitle(x)).unique()
# Out:
# array(['mr', 'mrs', 'miss', 'master', 'don', 'rev', 'dr', 'mme', 'ms',
#        'major', 'lady', 'sir', 'mlle', 'col', 'capt', 'the countess',
#        'jonkheer', 'dona'], dtype=object)

# %%
def GetTitle(name):
    title_group = {'mr' : 'Mr',
                   'mrs' : 'mrs',
                   'miss' : 'Miss',
                   'master' : 'Master',
                   'don' : 'Sir',
                   'rev' : 'Sir',
                   'dr' : 'Offier',
                   'mme' : 'Mrs',
                   'ms' : 'Mrs',
                   'major': 'Offier',
                   'lady' : 'Lady',
                   'sir' : 'Sir',
                   'mlle' : 'Miss',
                   'col' : 'Offier',
                   'capt' :'Offier',
                   'the countess' : 'Lady',
                   'jonkheer' : 'Sir',
                   'dona' : 'Lady'
                   
                   }
    first_name = name.split(',')[1]
    title = first_name.split('.')[0]
    title = title.strip().lower()
    return title_group[title]

# %%
df['Title'] = df.Name.map(lambda x : GetTitle(x))

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   mrs
# ...

# %%
df[df.Age.notnull()].boxplot('Age','Title');

# %%
TitleMedianAge = df.groupby('Title').Age.transform('median')
df.Age.fillna(TitleMedianAge , inplace = True)

# %%
df[df.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1309 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1309 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1309 non-null   object
#  11  Title     1309 non-null   object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 172.9+ KB

# %% [markdown]
#  # Outliers Detection
#  ### 1) By histogram
#  ### 2) By Boxplot
#  ### 3) By scatter Plot

# %%
df.Age.plot(kind = 'hist',bins = 20, color = 'c');

# %%
SqrtAge = np.sqrt(df.Age + 1.0)

# %%
SqrtAge.plot(kind = 'hist',color = 'c');

# %%
#df.loc[df.LogAge >8]

# %%
df.loc[df.Age > 70]
# Out:
#              Survived  Pclass  \
# PassengerId
# 97                0.0       1
# 117               0.0       3
# 494               0.0       1
# 631               1.0       1
# 852               0.0       3
# 988               NaN       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 97                                   Goldschmidt, Mr. George B    male  71.0
# 117                                       Connors, Mr. Patrick    male  70.5
# 494                                    Artagaveytia, Mr. Ramon    male  71.0
# 631                       Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 852                                        Svensson, Mr. Johan    male  74.0
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked Title
# PassengerId
# 97               0      0  PC 17754  34.6542    A5        C    Mr
# ...

# %%
df.loc[df.Fare == df.Fare.max()]
# Out:
#              Survived  Pclass  \
# PassengerId
# 259               1.0       1
# 680               1.0       1
# 738               1.0       1
# 1235              NaN       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 259                                           Ward, Miss. Anna  female  35.0
# 680                         Cardeza, Mr. Thomas Drake Martinez    male  36.0
# 738                                     Lesurer, Mr. Gustave J    male  35.0
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0
#
#              SibSp  Parch    Ticket      Fare        Cabin Embarked Title
# PassengerId
# 259              0      0  PC 17755  512.3292          NaN        C  Miss
# 680              0      1  PC 17755  512.3292  B51 B53 B55        C    Mr
# 738              0      0  PC 17755  512.3292         B101        C    Mr
# 1235             0      1  PC 17755  512.3292  B51 B53 B55        C   mrs

# %%
df.Fare.plot(kind= 'hist',bins = 20);

# %%
SqrtFare= np.log(df.Fare + 1.0)

# %%
SqrtFare.plot(kind = 'hist',bins =20);

# %%
logFare= np.log(df.Fare + 1.0)

# %%
logFare.plot(kind = 'hist',bins =20);

# %% [markdown]
# ### Binning

# %%
pd.qcut(df.Age,4).value_counts()
# Out:
# (22.0, 29.0]     413
# (0.169, 22.0]    391
# (35.5, 80.0]     323
# (29.0, 35.5]     182
# Name: Age, dtype: int64

# %%
pd.qcut(df.Age,4 ,labels =['very_low','low','high','very_high'])
# Out:
# PassengerId
# 1        very_low
# 2       very_high
# 3             low
# 4            high
# 5            high
#           ...
# 1305          low
# 1306    very_high
# 1307    very_high
# 1308          low
# 1309     very_low
# Name: Age, Length: 1309, dtype: category
# Categories (4, object): [very_low < low < high < very_high]

# %%
df['Fare_bin']= pd.qcut(df.Fare,4 ,labels =['very_low','low','high','very_high'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1309 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1309 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1309 non-null   object
#  11  Title     1309 non-null   object
#  12  Fare_bin  1309 non-null   category
# dtypes: category(1), float64(3), int64(3), object(6)
# memory usage: 174.4+ KB

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   mrs
# ...

# %% [markdown]
# # Feature Engineering

# %%
df['AgeState'] = np.where(df.Age >= 18,'Adult','Child')

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# 6                 0.0       3
# 7                 0.0       1
# 8                 0.0       3
# 9                 1.0       3
# 10                1.0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male  29.0
# ...

# %%
df.AgeState.value_counts()
# Out:
# Adult    1147
# Child     162
# Name: AgeState, dtype: int64

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].AgeState)
# Out:
# AgeState  Adult  Child
# Survived
# 0.0         495     54
# 1.0         279     63

# %% [markdown]
# ### Family Size feature

# %%
df['FamilySize'] = df.Parch + df.SibSp +1

# %%
df.loc[df.FamilySize==df.FamilySize.max(),['Name','Survived','FamilySize','Ticket']]
# Out:
#                                           Name  Survived  FamilySize    Ticket
# PassengerId
# 160                 Sage, Master. Thomas Henry       0.0          11  CA. 2343
# 181               Sage, Miss. Constance Gladys       0.0          11  CA. 2343
# 202                        Sage, Mr. Frederick       0.0          11  CA. 2343
# 325                   Sage, Mr. George John Jr       0.0          11  CA. 2343
# 793                    Sage, Miss. Stella Anna       0.0          11  CA. 2343
# 847                   Sage, Mr. Douglas Bullen       0.0          11  CA. 2343
# 864          Sage, Miss. Dorothy Edith "Dolly"       0.0          11  CA. 2343
# 1080                           Sage, Miss. Ada       NaN          11  CA. 2343
# 1234                     Sage, Mr. John George       NaN          11  CA. 2343
# 1252               Sage, Master. William Henry       NaN          11  CA. 2343
# 1257            Sage, Mrs. John (Annie Bullen)       NaN          11  CA. 2343

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].FamilySize)
# Out:
# FamilySize   1   2   3   4   5   6   7   8   11
# Survived
# 0.0         374  72  43   8  12  19   8   6   7
# 1.0         163  89  59  21   3   3   4   0   0

# %%
df.FamilySize.plot(kind = 'hist',bins = 20);

# %% [markdown]
# ### IsMother Feature

# %%
df['Ismother']= np.where(((df.Sex == 'F') & (df.Parch > 0) & (df.Age > 18) & (df.Title != 'Miss')), 1,0)

# %%
pd.crosstab(df[df.Survived != -888].Survived, df[df.Survived != -888].Ismother)
# Out:
# Ismother    0
# Survived
# 0.0       549
# 1.0       342

# %% [markdown]
# ### Deck

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   mrs
# ...

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.Cabin
# Out:
# PassengerId
# 1        NaN
# 2        C85
# 3        NaN
# 4       C123
# 5        NaN
#         ...
# 1305     NaN
# 1306    C105
# 1307     NaN
# 1308     NaN
# 1309     NaN
# Name: Cabin, Length: 1309, dtype: object

# %%
df.loc[df.Cabin == 'T']
# Out:
#              Survived  Pclass                          Name   Sex   Age  \
# PassengerId
# 340               0.0       1  Blackwell, Mr. Stephen Weart  male  45.0
#
#              SibSp  Parch  Ticket  Fare Cabin Embarked Title   Fare_bin  \
# PassengerId
# 340              0      0  113784  35.5     T        S    Mr  very_high
#
#             AgeState  FamilySize  Ismother
# PassengerId
# 340            Adult           1         0

# %%
df.loc[df.Cabin == 'T','Cabin'] = np.NaN

# %%
def get_deck(cabin):
    return np.where(pd.notnull(cabin),str(cabin)[0].upper(),'Z')
df['deck'] = df['Cabin'].map(lambda x : get_deck(x))

# %%
df.deck
# Out:
# PassengerId
# 1       Z
# 2       C
# 3       Z
# 4       C
# 5       Z
#        ..
# 1305    Z
# 1306    C
# 1307    Z
# 1308    Z
# 1309    Z
# Name: deck, Length: 1309, dtype: object

# %%
df.deck.value_counts()
# Out:
# Z    1015
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# Name: deck, dtype: int64

# %%
pd.crosstab(df[df.Survived !=-888].Survived, df[df.Survived!=-888].deck)
# Out:
# deck      A   B   C   D   E  F  G    Z
# Survived
# 0.0       8  12  24   8   8  5  2  482
# 1.0       7  35  35  25  24  8  2  206

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    float64
#  1   Pclass      1309 non-null   int64
#  2   Name        1309 non-null   object
#  3   Sex         1309 non-null   object
#  4   Age         1309 non-null   float64
#  5   SibSp       1309 non-null   int64
#  6   Parch       1309 non-null   int64
#  7   Ticket      1309 non-null   object
#  8   Fare        1309 non-null   float64
#  9   Cabin       294 non-null    object
#  10  Embarked    1309 non-null   object
#  11  Title       1309 non-null   object
#  12  Fare_bin    1309 non-null   category
#  13  AgeState    1309 non-null   object
#  14  FamilySize  1309 non-null   int64
#  15  Ismother    1309 non-null   int32
#  16  deck        1309 non-null   object
# dtypes: category(1), float64(3), int32(1), int64(4), object(8)
# memory usage: 210.2+ KB

# %% [markdown]
# ### categorical feature encoding

# %%
df['ismale'] = np.where(df.Sex =='Male',1,0)

# %%
df = pd.get_dummies(df,columns = ['deck','Pclass','Title','Fare_bin','Embarked','AgeState'])

# %%
df.head()
# Out:
#              Survived                                               Name  \
# PassengerId
# 1                 0.0                            Braund, Mr. Owen Harris
# 2                 1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                 1.0                             Heikkinen, Miss. Laina
# 4                 1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                 0.0                           Allen, Mr. William Henry
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 2            female  38.0      1      0          PC 17599  71.2833   C85
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
#
# ...

# %%
df.Ticket
# Out:
# PassengerId
# 1                A/5 21171
# 2                 PC 17599
# 3         STON/O2. 3101282
# 4                   113803
# 5                   373450
#                ...
# 1305             A.5. 3236
# 1306              PC 17758
# 1307    SOTON/O.Q. 3101262
# 1308                359309
# 1309                  2668
# Name: Ticket, Length: 1309, dtype: object

# %%
pd.crosstab(df[df.Survived !=-888].Survived, df[df.Survived!=-888].Ticket)
# Out:
# Ticket    110152  110413  110465  110564  110813  111240  111320  111361  \
# Survived
# 0.0            0       1       2       0       0       1       1       0
# 1.0            3       2       0       1       1       0       0       2
#
# Ticket    111369  111426  ...  STON/O2. 3101290  SW/PP 751  W./C. 14258  \
# Survived                  ...
# 0.0            0       0  ...                 1          0            0
# 1.0            1       1  ...                 0          1            1
#
# Ticket    W./C. 14263  W./C. 6607  W./C. 6608  W./C. 6609  W.E.P. 5734  \
# Survived
# 0.0                 1           2           4           1            1
# 1.0                 0           0           0           0            0
#
# Ticket    W/C 14208  WE/P 5735
# Survived
# 0.0               1          1
# 1.0               0          1
#
# [2 rows x 681 columns]

# %%
#df.plot.scatter(x='Ticket',y='Survived',color ='c')

# %%
df.drop(['Cabin','Name','Ticket','Parch','SibSp','Sex'], axis =1,inplace= True)

# %%
# To reorder the column
columns = [column for column in df.columns if column != 'Survived']
columns = ['Survived'] + columns
df = df[columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 34 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Survived            891 non-null    float64
#  1   Age                 1309 non-null   float64
#  2   Fare                1309 non-null   float64
#  3   FamilySize          1309 non-null   int64
#  4   Ismother            1309 non-null   int32
#  5   ismale              1309 non-null   int32
#  6   deck_A              1309 non-null   uint8
#  7   deck_B              1309 non-null   uint8
#  8   deck_C              1309 non-null   uint8
#  9   deck_D              1309 non-null   uint8
#  10  deck_E              1309 non-null   uint8
#  11  deck_F              1309 non-null   uint8
#  12  deck_G              1309 non-null   uint8
#  13  deck_Z              1309 non-null   uint8
#  14  Pclass_1            1309 non-null   uint8
# ...

# %%
### Creating path
#path  = 'C:\Users\BLESS\Desktop\titanic\data\processed'
processed_data_path = os.path.join(os.path.pardir,'data','processed')
write_Train_path = os.path.join(processed_data_path,'train.csv')
write_test_path  = os.path.join(processed_data_path, 'test.csv')

# %%
### Save the data
#### train data
df.loc[df.Survived != -888].to_csv(write_Train_path)
#### test data
columns = [column for column in df.columns if column != 'Survived']
df.loc[df.Survived == -888, columns].to_csv(write_test_path)
